# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
parent_dir = os.path.dirname(os.getcwd())
path = parent_dir 
save_path = parent_dir + '/'
from optimization import *
import warnings
warnings.filterwarnings('ignore', category=UserWarning)
color_palette = ['#332288',  '#117733', '#44AA99', '#88CCEE', '#DDCC77', '#CC6677', '#AA4499', '#882255']

# %% [markdown]
# ## Figure A.3: Annual Costs with Dynamic + V1G

# %%
def replace_nan_with_previous_value(cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v2g_everywhere, cost_mat_v1g_dynamic, cost_mat_v2g_limited):
    '''Replace any nan weeks with the previous week's value and reshape the matrices to Jan-Jan format.'''
    # print(np.shape(cost_mat_controlled))
    # print(np.shape(cost_mat_v2g_limited))
    # print(np.shape(cost_mat_v1g_dynamic))
    for vin in np.arange(cost_mat_controlled.shape[0]):
        for week in np.arange(cost_mat_controlled.shape[1]):
            if np.isnan(cost_mat_controlled[vin, week]):
                if week == 0:
                    cost_mat_controlled[vin, week] = 0
                else:
                    cost_mat_controlled[vin, week] = cost_mat_controlled[vin, week-1]
            if np.isnan(cost_mat_uncontrolled[vin, week]):
                if week == 0:
                    cost_mat_uncontrolled[vin, week] = 0
                else:
                    cost_mat_uncontrolled[vin, week] = cost_mat_uncontrolled[vin, week-1]
            if np.isnan(cost_mat_v2g_home[vin, week]):
                if week == 0:
                    cost_mat_v2g_home[vin, week] = 0
                else:
                    cost_mat_v2g_home[vin, week] = cost_mat_v2g_home[vin, week-1]
            if np.isnan(cost_mat_v2g_everywhere[vin, week]):
                if week == 0:
                    cost_mat_v2g_everywhere[vin, week] = 0
                else:
                    cost_mat_v2g_everywhere[vin, week] = cost_mat_v2g_everywhere[vin, week-1]
            if np.isnan(cost_mat_v1g_dynamic[vin, week]):
                if week == 0:
                    cost_mat_v1g_dynamic[vin, week] = 0
                else:
                    cost_mat_v1g_dynamic[vin, week] = cost_mat_v1g_dynamic[vin, week-1]
            if np.isnan(cost_mat_v2g_limited[vin, week]):
                if week == 0:
                    cost_mat_v2g_limited[vin, week] = 0
                else:
                    cost_mat_v2g_limited[vin, week] = cost_mat_v2g_limited[vin, week-1]


    #find rows that sum up to zero from controlled and remove them from cost matrices
    zero_idx = np.all(cost_mat_controlled == 0, axis=1)
    cost_mat_controlled = cost_mat_controlled[~zero_idx]
    cost_mat_uncontrolled = cost_mat_uncontrolled[~zero_idx]
    cost_mat_v2g_home = cost_mat_v2g_home[~zero_idx]
    cost_mat_v2g_everywhere = cost_mat_v2g_everywhere[~zero_idx]
    cost_mat_v1g_dynamic = cost_mat_v1g_dynamic[~zero_idx]
    cost_mat_v2g_limited = cost_mat_v2g_limited[~zero_idx]

    #order the matrices so data is Jan-Jan
    cost_mat_uncontrolled_jan = np.zeros((cost_mat_uncontrolled.shape[0], 52))
    cost_mat_controlled_jan = np.zeros((cost_mat_controlled.shape[0], 52))
    cost_mat_v2g_home_jan = np.zeros((cost_mat_v2g_home.shape[0], 52))
    cost_mat_v2g_everywhere_jan = np.zeros((cost_mat_v2g_everywhere.shape[0], 52)) 
    cost_mat_v1g_dynamic_jan = np.zeros((cost_mat_v1g_dynamic.shape[0], 52))
    cost_mat_v2g_limited_jan = np.zeros((cost_mat_v2g_limited.shape[0], 52))

    num_weeks = 52
    year_splice = 22
    year_splice_2 = num_weeks-year_splice
    cost_mat_uncontrolled_jan[:, 0:year_splice] = cost_mat_uncontrolled[:, year_splice_2:num_weeks]
    cost_mat_uncontrolled_jan[:, year_splice:num_weeks] = cost_mat_uncontrolled[:, 0:year_splice_2]
    cost_mat_controlled_jan[:, 0:year_splice] = cost_mat_controlled[:, year_splice_2:num_weeks] 
    cost_mat_controlled_jan[:, year_splice:num_weeks] = cost_mat_controlled[:, 0:year_splice_2]
    cost_mat_v2g_home_jan[:, 0:year_splice] = cost_mat_v2g_home[:, year_splice_2:num_weeks]
    cost_mat_v2g_home_jan[:, year_splice:num_weeks] = cost_mat_v2g_home[:, 0:year_splice_2]
    cost_mat_v2g_everywhere_jan[:, 0:year_splice] = cost_mat_v2g_everywhere[:, year_splice_2:num_weeks]
    cost_mat_v2g_everywhere_jan[:, year_splice:num_weeks] = cost_mat_v2g_everywhere[:, 0:year_splice_2]
    cost_mat_v1g_dynamic_jan[:, 0:year_splice] = cost_mat_v1g_dynamic[:, year_splice_2:num_weeks]
    cost_mat_v1g_dynamic_jan[:, year_splice:num_weeks] = cost_mat_v1g_dynamic[:, 0:year_splice_2]
    cost_mat_v2g_limited_jan[:, 0:year_splice] = cost_mat_v2g_limited[:, year_splice_2:num_weeks]
    cost_mat_v2g_limited_jan[:, year_splice:num_weeks] = cost_mat_v2g_limited[:, 0:year_splice_2]

    return cost_mat_uncontrolled_jan, cost_mat_controlled_jan, cost_mat_v2g_home_jan, cost_mat_v2g_everywhere_jan, cost_mat_v1g_dynamic_jan, cost_mat_v2g_limited_jan

# %%
def plot_costs(ax, cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v1g_dynamic, num_periods, circuit):
    ax.plot(np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0), color = color_palette[0], linewidth = 2, label='Baseline')
    ax.plot(np.mean(np.cumsum( cost_mat_controlled, axis=1), axis=0), color = color_palette[1], linewidth = 2, label='Managed')
    ax.plot(np.mean(np.cumsum( cost_mat_v1g_dynamic, axis=1), axis=0), color = color_palette[5], label='Managed + Dynamic Price')
    ax.plot(np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0), color = color_palette[3], label='V2G Home')

    ax.fill_between(np.arange(cost_mat_uncontrolled.shape[1]), np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0) - np.std(np.cumsum(cost_mat_uncontrolled, axis=1), axis=0), np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0) + np.std(np.cumsum(cost_mat_uncontrolled, axis=1), axis=0), color = color_palette[0], alpha = 0.15)
    ax.fill_between(np.arange(cost_mat_controlled.shape[1]), np.mean(np.cumsum( cost_mat_controlled, axis=1), axis=0) - np.std(np.cumsum(cost_mat_controlled, axis=1), axis=0), np.mean(np.cumsum( cost_mat_controlled, axis=1), axis=0) + np.std(np.cumsum(cost_mat_controlled, axis=1), axis=0), color = color_palette[1], alpha = 0.15)
    ax.fill_between(np.arange(cost_mat_v1g_dynamic.shape[1]), np.mean(np.cumsum( cost_mat_v1g_dynamic, axis=1), axis=0) - np.std(np.cumsum(cost_mat_v1g_dynamic, axis=1), axis=0), np.mean(np.cumsum( cost_mat_v1g_dynamic, axis=1), axis=0) + np.std(np.cumsum(cost_mat_v1g_dynamic, axis=1), axis=0), color = color_palette[5], alpha = 0.15)
    ax.fill_between(np.arange(cost_mat_v2g_home.shape[1]), np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0) - np.std(np.cumsum(cost_mat_v2g_home, axis=1), axis=0), np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0) + np.std(np.cumsum(cost_mat_v2g_home, axis=1), axis=0), color = color_palette[3], alpha = 0.15)
    #set legend
    ax.legend(loc='lower left', fontsize=13)

    #add light gray horizontal line at y=0
    ax.axhline(0, color='lightgray', linestyle='--', linewidth= 1.5)

    ax.set_xlabel('Month', fontsize=14)
    ax.set_ylabel('Cumul. Chg. Cost [$1000]', fontsize=13)
    ax.set_xlim([0,num_periods+6])
    ax.set_xticks(np.linspace(0, num_periods-1, 5 ))
    ax.set_xticklabels(['Jan', 'April', 'July', 'Oct.', "Jan."], fontsize=14)
    ax.tick_params(axis='both', which='major', labelsize=14)
    ax.annotate('$'+str(np.round(np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0)[-1], 0))[:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0)[-1]+90), xycoords= 'data', ha='center', fontsize=13)
    ax.annotate('$'+str(np.round(np.mean(np.cumsum( cost_mat_controlled, axis=1), axis=0)[-1], 0))[:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_controlled, axis=1), axis=0)[-1]-90), xycoords= 'data', ha='center', fontsize=13)
    if np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1] < 0:
        ax.annotate('-$'+str(np.round(np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1], 0))[1:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1]+20), xycoords= 'data', ha='center', fontsize=13)
        ax.annotate('-$'+str(np.round(np.mean(np.cumsum( cost_mat_v1g_dynamic, axis=1), axis=0)[-1], 0))[1:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_v1g_dynamic, axis=1), axis=0)[-1]-20), xycoords= 'data', ha='center', fontsize=13)
    else:
        ax.annotate('$'+str(np.round(np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1], 0))[:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1]-20), xycoords= 'data', ha='center', fontsize=13)
        ax.annotate('$'+str(np.round(np.mean(np.cumsum( cost_mat_v1g_dynamic, axis=1), axis=0)[-1], 0))[:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_v1g_dynamic, axis=1), axis=0)[-1]+20), xycoords= 'data', ha='center', fontsize=13)

    min=-3500
    max=3000
    ax.set_ylim(min, max)
    ax.set_yticklabels([str(int(x/1000)) for x in np.arange(min-500, max+1, 1000)], fontsize=14)        
    ax.annotate('Circuit ' + str(circuit)[-1], xy=(0.1, .90), xycoords='axes fraction', ha='center', fontsize=16)

# %%
def plot_costs_limited(ax, cost_mat_uncontrolled, cost_mat_v2g_home, cost_mat_v2g_limited,  num_periods, circuit):
    ax.plot(np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0), color = color_palette[0], linewidth = 2, label='Baseline')
    ax.plot(np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0), color = color_palette[3], label='V2G Home')
    ax.plot(np.mean(np.cumsum( cost_mat_v2g_limited, axis=1), axis=0), color = color_palette[7], label='V2G Limited')

    ax.fill_between(np.arange(cost_mat_uncontrolled.shape[1]), np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0) - np.std(np.cumsum(cost_mat_uncontrolled, axis=1), axis=0), np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0) + np.std(np.cumsum(cost_mat_uncontrolled, axis=1), axis=0), color = color_palette[0], alpha = 0.15)
    ax.fill_between(np.arange(cost_mat_v2g_home.shape[1]), np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0) - np.std(np.cumsum(cost_mat_v2g_home, axis=1), axis=0), np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0) + np.std(np.cumsum(cost_mat_v2g_home, axis=1), axis=0), color = color_palette[3], alpha = 0.15)
    ax.fill_between(np.arange(cost_mat_v2g_limited.shape[1]), np.mean(np.cumsum( cost_mat_v2g_limited, axis=1), axis=0) - np.std(np.cumsum(cost_mat_v2g_limited, axis=1), axis=0), np.mean(np.cumsum( cost_mat_v2g_limited, axis=1), axis=0) + np.std(np.cumsum(cost_mat_v2g_limited, axis=1), axis=0), color = color_palette[7], alpha = 0.15)

    #set legend
    ax.legend(loc='lower left', fontsize=13)

    #add light gray horizontal line at y=0
    ax.axhline(0, color='lightgray', linestyle='--', linewidth= 1.5)

    ax.set_xlabel('Month', fontsize=14)
    ax.set_ylabel('Cumul. Chg. Cost [$1000]', fontsize=13)
    ax.set_xlim([0,num_periods+6])
    ax.set_xticks(np.linspace(0, num_periods-1, 5 ))
    ax.set_xticklabels(['Jan', 'April', 'July', 'Oct.', "Jan."], fontsize=14)
    ax.tick_params(axis='both', which='major', labelsize=14)
    ax.annotate('$'+str(np.round(np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0)[-1], 0))[:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0)[-1]+20), xycoords= 'data', ha='center', fontsize=13)
    if np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1] < 0:
        ax.annotate('-$'+str(np.round(np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1], 0))[1:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1]+20), xycoords= 'data', ha='center', fontsize=13)
        ax.annotate('-$'+str(np.round(np.mean(np.cumsum( cost_mat_v2g_limited, axis=1), axis=0)[-1], 0))[1:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_v2g_limited, axis=1), axis=0)[-1]-20), xycoords= 'data', ha='center', fontsize=13)
    else:
        ax.annotate('$'+str(np.round(np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1], 0))[:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1]-20), xycoords= 'data', ha='center', fontsize=13)
        ax.annotate('$'+str(np.round(np.mean(np.cumsum( cost_mat_v2g_limited, axis=1), axis=0)[-1], 0))[:-2], xy=(54.5, np.mean(np.cumsum( cost_mat_v2g_limited, axis=1), axis=0)[-1]+20), xycoords= 'data', ha='center', fontsize=13)

    min=-3500
    max=3000
    ax.set_ylim(min, max)
    ax.set_yticklabels([str(int(x/1000)) for x in np.arange(min-500, max+1, 1000)], fontsize=14)        
    ax.annotate('Circuit ' + str(circuit)[-1], xy=(0.1, .90), xycoords='axes fraction', ha='center', fontsize=16)

# %%
def load_results(results_path, period_string):
    '''Load the cost results into matrices from the specified path and period string.'''
    vin_length = 749
    cost_mat_uncontrolled = []
    cost_mat_controlled = []
    cost_mat_v2g_home = []
    cost_mat_v2g_everywhere = []
    cost_mat_v1g_dynamic = []
    cost_mat_v2g_limited = []

    for vin in np.arange(1,vin_length):
        #skip the vins that do not have data 
        try:
            cost_mat_v2g_limited.append( pd.read_csv(results_path + 'cost_v2g_home_limited_' + period_string + '_vin_' +str(vin) + '.csv').iloc[:,1])

            cost_mat_uncontrolled.append( pd.read_csv(results_path + 'cost_uncontrolled_' + period_string + '_vin_' +str(vin) + '.csv').iloc[:,1])
            cost_mat_controlled.append( pd.read_csv(results_path + 'cost_no_v2g_' + period_string + '_vin_' +str(vin) + '.csv').iloc[:,1])
            cost_mat_v2g_home.append( pd.read_csv(results_path + 'cost_v2g_home_' + period_string + '_vin_' +str(vin) + '.csv').iloc[:,1])
            cost_mat_v2g_everywhere.append(pd.read_csv(results_path + 'cost_v2g_everywhere_' + period_string + '_vin_' +str(vin) + '.csv').iloc[:,1])
            cost_mat_v1g_dynamic.append( pd.read_csv(results_path + 'cost_v1g_dynamic_' + period_string + '_vin_' +str(vin) + '.csv').iloc[:,1])

        except:
            pass

    cost_mat_uncontrolled = np.array(cost_mat_uncontrolled)
    cost_mat_controlled = np.array(cost_mat_controlled)
    cost_mat_v2g_home = np.array(cost_mat_v2g_home)
    cost_mat_v2g_everywhere = np.array(cost_mat_v2g_everywhere)
    cost_mat_v1g_dynamic = np.array(cost_mat_v1g_dynamic)
    cost_mat_v2g_limited = np.array(cost_mat_v2g_limited)
    #print all shapes
    return cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v2g_everywhere, cost_mat_v1g_dynamic, cost_mat_v2g_limited

# %%
aging = 'batt_aging_0'
period_string = '2024-06-03_to_2025-06-01'

fig, ax = plt.subplots(4, 2, figsize=(19, 20))
ax = ax.flatten()
plt.subplots_adjust(wspace=0.13)
plt.subplots_adjust(hspace=0.2)
fig_label = ['a', 'b', 'c', 'd']
fig_label_2 = ['e', 'f', 'g', 'h']

for i, circuit in enumerate(['cir_1', 'cir_2', 'cir_3', 'cir_4']):
    print('Circuit ' + str(circuit)[-1])
    #load results
    results_path = 'Results/'+ circuit+ '/' + aging + '/' + 'elrp_1_'
    cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v2g_everywhere, cost_mat_v1g_dynamic, cost_mat_v2g_limited = load_results(results_path, period_string)
    cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v2g_everywhere, cost_mat_v1g_dynamic, cost_mat_v2g_limited = replace_nan_with_previous_value(cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v2g_everywhere, cost_mat_v1g_dynamic, cost_mat_v2g_limited)
    num_periods = cost_mat_uncontrolled.shape[1]
    plot_costs(ax[i], cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v1g_dynamic, num_periods, circuit)
    print(str(np.round(np.mean(np.cumsum( cost_mat_uncontrolled, axis=1), axis=0)[-1],2)) + ' & ' + str(np.round(np.mean(np.cumsum( cost_mat_controlled, axis=1), axis=0)[-1], 2)) + ' & ' + str(np.round(np.mean(np.cumsum(cost_mat_v1g_dynamic, axis=1), axis=0)[-1], 2)) + ' & ' + str(np.round(np.mean(np.cumsum( cost_mat_v2g_home, axis=1), axis=0)[-1], 2)) + ' & ' + str(np.round(np.mean(np.cumsum( cost_mat_v2g_everywhere, axis=1), axis=0)[-1], 2)) + ' & ' + str(np.round(np.mean(np.cumsum( cost_mat_v2g_limited, axis=1), axis=0)[-1], 2)) )
    ax[i].annotate(fig_label[i]+'.', xy=(-0.1, 1.05), xycoords='axes fraction', ha='center', fontsize=16)

    plot_costs_limited(ax[i+4-1], cost_mat_uncontrolled,  cost_mat_v2g_home, cost_mat_v2g_limited, num_periods, circuit)
    ax[i+4-1].annotate(fig_label_2[i]+'.', xy=(-0.08, 1.05), xycoords='axes fraction', ha='center', fontsize=16)

plt.savefig(save_path + 'A3_costs_v1g_dynamic.pdf', bbox_inches='tight')
# Out:
# Circuit 1
# 1927.49 & 1730.71 & 0.0 & -1198.2 & -1336.06 & -362.31
# Circuit 2
# 1932.06 & 1734.45 & 0.0 & -906.71 & -1093.45 & -84.89
# Circuit 3
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[72], line 16
#      14 results_path = 'Results/'+ circuit+ '/' + aging + '/' + 'elrp_1_'
#      15 cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v2g_everywhere, cost_mat_v1g_dynamic, cost_mat_v2g_limited = load_results(results_path, period_string)
# ---> 16 cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v2g_everywhere, cost_mat_v1g_dynamic, cost_mat_v2g_limited = replace_nan_with_previous_value(cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v2g_everywhere, cost_mat_v1g_dynamic, cost_mat_v2g_limited)
#      17 num_periods = cost_mat_uncontrolled.shape[1]
#      18 plot_costs(ax[i], cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v1g_dynamic, num_periods, circuit)
#
# Cell In[67], line 41, in replace_nan_with_previous_value(cost_mat_uncontrolled, cost_mat_controlled, cost_mat_v2g_home, cost_mat_v2g_everywhere, cost_mat_v1g_dynamic, cost_mat_v2g_limited)
#      37                 cost_mat_v2g_limited[vin, week] = cost_mat_v2g_limited[vin, week-1]
#      40 #find rows that sum up to zero from controlled and remove them from cost matrices
# ---> 41 zero_idx = np.all(cost_mat_controlled == 0, axis=1)
#      42 cost_mat_controlled = cost_mat_controlled[~zero_idx]
#      43 cost_mat_uncontrolled = cost_mat_uncontrolled[~zero_idx]
#
# File <__array_function__ internals>:200, in all(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2515, in all(a, axis, out, keepdims, where)
#    2432 @array_function_dispatch(_all_dispatcher)
#    2433 def all(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2434     """
#    2435     Test whether all array elements along a given axis evaluate to True.
#    2436
#    (...)
#    2513
#    2514     """
# -> 2515     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#    2516                           keepdims=keepdims, where=where)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# AxisError: axis 1 is out of bounds for array of dimension 1
